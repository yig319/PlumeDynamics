# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('../../../Downloads/Camera_13_50_21_001.bmp')
plt.figure(figsize=(6,3))
plt.imshow(img)
plt.colorbar()
plt.axis('off')
plt.title('f=4')
plt.tight_layout()
plt.show()

# %%
img = plt.imread('../../../Downloads/Camera_13_47_28_001.bmp')
plt.figure(figsize=(6,3))
plt.imshow(img)
plt.colorbar()
plt.axis('off')
plt.title('f=8')
plt.tight_layout()
plt.show()

# %%
img = plt.imread('../../../Downloads/Camera_13_49_59_001.bmp')
plt.figure(figsize=(6,3))
plt.imshow(img)
plt.colorbar()
plt.axis('off')
plt.title('f=5.6')
plt.tight_layout()
plt.show()
